# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment4/blob/master/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
batch_size = 64  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
#Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# %%
#Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
#Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    
    lr = 1e-3
    #if epoch > 40:
     #   lr *= le-1
    #elif epoch > 30:
     #   lr *= 1e-2
    #elif epoch > 20:
     #   lr *= 1e-2
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
def resnet_layer(inputs,
                 num_filters=110,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization(momentum=0.355)(x)
            x=Dropout(0.0712)(x)
          #  x=Dropout(0.0774)(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization(momentum=0.355)(x)
            x=Dropout(0.0712)(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    
        
   
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 110
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
   # x = AveragePooling2D(pool_size=4)(x)
    y = GlobalAveragePooling2D()(x)
    #outputs=Activation('softmax')(y)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 1:
    
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Learning rate:  0.001
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 110)  3080        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 110)  440         conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 110)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 110)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 110)  109010      activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 110)  440         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 110)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 110)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 110)  109010      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 110)  440         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 110)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 110)  0           activation_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 110)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 110)  109010      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 110)  440         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 110)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 110)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 110)  109010      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 110)  440         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 110)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 110)  0           activation_3[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 110)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 220)  218020      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 220)  880         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 220)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 220)  0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 220)  435820      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 220)  880         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 220)  24420       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 220)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 220)  0           conv2d_8[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 220)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 220)  435820      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 220)  880         conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 220)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 220)  0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 220)  435820      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 220)  880         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 220)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 220)  0           activation_7[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 220)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 440)    871640      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 440)    1760        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8, 8, 440)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 440)    0           dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 440)    1742840     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 440)    1760        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 440)    97240       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 440)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 440)    0           conv2d_13[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 440)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 440)    1742840     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 440)    1760        conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 440)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 440)    0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 440)    1742840     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 440)    1760        conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 440)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 440)    0           activation_11[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 440)    0           add_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 440)          0           activation_13[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           4410        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 8,203,590
# Trainable params: 8,197,210
# Non-trainable params: 6,380
# __________________________________________________________________________________________________
# ResNet14v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=2,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
#Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    get_random_eraser(v_l=0, v_h=1)
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        
       # get_random_eraser(v_l=0, v_h=1)
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
#Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs,verbose=2,workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# Learning rate:  0.001
#  - 72s - loss: 2.0417 - acc: 0.5030 - val_loss: 1.6121 - val_acc: 0.6268
#
# Epoch 00001: val_acc improved from -inf to 0.62680, saving model to /content/saved_models/cifar10_ResNet14v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
#  - 64s - loss: 1.3621 - acc: 0.6909 - val_loss: 1.2614 - val_acc: 0.7339
#
# Epoch 00002: val_acc improved from 0.62680 to 0.73390, saving model to /content/saved_models/cifar10_ResNet14v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
#  - 63s - loss: 1.1616 - acc: 0.7512 - val_loss: 1.1354 - val_acc: 0.7642
#
# Epoch 00003: val_acc improved from 0.73390 to 0.76420, saving model to /content/saved_models/cifar10_ResNet14v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
#  - 63s - loss: 1.0699 - acc: 0.7770 - val_loss: 1.0571 - val_acc: 0.7875
#
# Epoch 00004: val_acc improved from 0.76420 to 0.78750, saving model to /content/saved_models/cifar10_ResNet14v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
#  - 63s - loss: 1.0100 - acc: 0.7968 - val_loss: 0.9724 - val_acc: 0.8151
#
# Epoch 00005: val_acc improved from 0.78750 to 0.81510, saving model to /content/saved_models/cifar10_ResNet14v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
#  - 63s - loss: 0.9681 - acc: 0.8080 - val_loss: 0.9364 - val_acc: 0.8243
#
# Epoch 00006: val_acc improved from 0.81510 to 0.82430, saving model to /content/saved_models/cifar10_ResNet14v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
#  - 63s - loss: 0.9265 - acc: 0.8246 - val_loss: 0.9526 - val_acc: 0.8110
#
# Epoch 00007: val_acc did not improve from 0.82430
# Epoch 8/50
# Learning rate:  0.001
#  - 63s - loss: 0.9039 - acc: 0.8260 - val_loss: 0.8945 - val_acc: 0.8327
#
# Epoch 00008: val_acc improved from 0.82430 to 0.83270, saving model to /content/saved_models/cifar10_ResNet14v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
#  - 63s - loss: 0.8728 - acc: 0.8369 - val_loss: 0.8761 - val_acc: 0.8356
#
# Epoch 00009: val_acc improved from 0.83270 to 0.83560, saving model to /content/saved_models/cifar10_ResNet14v1_model.009.h5
# Epoch 10/50
# Learning rate:  0.001
#  - 63s - loss: 0.8452 - acc: 0.8431 - val_loss: 0.8528 - val_acc: 0.8380
#
# Epoch 00010: val_acc improved from 0.83560 to 0.83800, saving model to /content/saved_models/cifar10_ResNet14v1_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
#  - 63s - loss: 0.8180 - acc: 0.8485 - val_loss: 0.9336 - val_acc: 0.8226
#
# Epoch 00011: val_acc did not improve from 0.83800
# Epoch 12/50
# Learning rate:  0.0001
#  - 63s - loss: 0.6581 - acc: 0.8977 - val_loss: 0.6750 - val_acc: 0.8905
#
# Epoch 00012: val_acc improved from 0.83800 to 0.89050, saving model to /content/saved_models/cifar10_ResNet14v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.0001
#  - 63s - loss: 0.5879 - acc: 0.9125 - val_loss: 0.6161 - val_acc: 0.9009
#
# Epoch 00013: val_acc improved from 0.89050 to 0.90090, saving model to /content/saved_models/cifar10_ResNet14v1_model.013.h5
# Epoch 14/50
# Learning rate:  0.0001
#  - 63s - loss: 0.5453 - acc: 0.9214 - val_loss: 0.5931 - val_acc: 0.9052
#
# Epoch 00014: val_acc improved from 0.90090 to 0.90520, saving model to /content/saved_models/cifar10_ResNet14v1_model.014.h5
# Epoch 15/50
# Learning rate:  0.0001
#  - 63s - loss: 0.5114 - acc: 0.9262 - val_loss: 0.5753 - val_acc: 0.9088
#
# Epoch 00015: val_acc improved from 0.90520 to 0.90880, saving model to /content/saved_models/cifar10_ResNet14v1_model.015.h5
# Epoch 16/50
# Learning rate:  0.0001
#  - 64s - loss: 0.4857 - acc: 0.9314 - val_loss: 0.5387 - val_acc: 0.9134
#
# Epoch 00016: val_acc improved from 0.90880 to 0.91340, saving model to /content/saved_models/cifar10_ResNet14v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.0001
#  - 64s - loss: 0.4631 - acc: 0.9346 - val_loss: 0.5422 - val_acc: 0.9108
#
# Epoch 00017: val_acc did not improve from 0.91340
# Epoch 18/50
# Learning rate:  0.0001
#  - 63s - loss: 0.4443 - acc: 0.9380 - val_loss: 0.5219 - val_acc: 0.9158
#
# Epoch 00018: val_acc improved from 0.91340 to 0.91580, saving model to /content/saved_models/cifar10_ResNet14v1_model.018.h5
# Epoch 19/50
# Learning rate:  0.0001
#  - 63s - loss: 0.4228 - acc: 0.9418 - val_loss: 0.5096 - val_acc: 0.9187
#
# Epoch 00019: val_acc improved from 0.91580 to 0.91870, saving model to /content/saved_models/cifar10_ResNet14v1_model.019.h5
# Epoch 20/50
# Learning rate:  0.0001
#  - 63s - loss: 0.4107 - acc: 0.9438 - val_loss: 0.5150 - val_acc: 0.9136
#
# Epoch 00020: val_acc did not improve from 0.91870
# Epoch 21/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3904 - acc: 0.9497 - val_loss: 0.5144 - val_acc: 0.9129
#
# Epoch 00021: val_acc did not improve from 0.91870
# Epoch 22/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3800 - acc: 0.9514 - val_loss: 0.4979 - val_acc: 0.9184
#
# Epoch 00022: val_acc did not improve from 0.91870
# Epoch 23/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3668 - acc: 0.9539 - val_loss: 0.4979 - val_acc: 0.9189
#
# Epoch 00023: val_acc improved from 0.91870 to 0.91890, saving model to /content/saved_models/cifar10_ResNet14v1_model.023.h5
# Epoch 24/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3552 - acc: 0.9561 - val_loss: 0.5035 - val_acc: 0.9165
#
# Epoch 00024: val_acc did not improve from 0.91890
# Epoch 25/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3496 - acc: 0.9571 - val_loss: 0.4892 - val_acc: 0.9207
#
# Epoch 00025: val_acc improved from 0.91890 to 0.92070, saving model to /content/saved_models/cifar10_ResNet14v1_model.025.h5
# Epoch 26/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3364 - acc: 0.9603 - val_loss: 0.4924 - val_acc: 0.9163
#
# Epoch 00026: val_acc did not improve from 0.92070
# Epoch 27/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3286 - acc: 0.9619 - val_loss: 0.4710 - val_acc: 0.9208
#
# Epoch 00027: val_acc improved from 0.92070 to 0.92080, saving model to /content/saved_models/cifar10_ResNet14v1_model.027.h5
# Epoch 28/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3181 - acc: 0.9646 - val_loss: 0.5197 - val_acc: 0.9146
#
# Epoch 00028: val_acc did not improve from 0.92080
# Epoch 29/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3132 - acc: 0.9654 - val_loss: 0.4769 - val_acc: 0.9207
#
# Epoch 00029: val_acc did not improve from 0.92080
# Epoch 30/50
# Learning rate:  0.0001
#  - 63s - loss: 0.3047 - acc: 0.9674 - val_loss: 0.4776 - val_acc: 0.9226
#
# Epoch 00030: val_acc improved from 0.92080 to 0.92260, saving model to /content/saved_models/cifar10_ResNet14v1_model.030.h5
# Epoch 31/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2974 - acc: 0.9692 - val_loss: 0.4609 - val_acc: 0.9234
#
# Epoch 00031: val_acc improved from 0.92260 to 0.92340, saving model to /content/saved_models/cifar10_ResNet14v1_model.031.h5
# Epoch 32/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2957 - acc: 0.9695 - val_loss: 0.4691 - val_acc: 0.9227
#
# Epoch 00032: val_acc did not improve from 0.92340
# Epoch 33/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2886 - acc: 0.9702 - val_loss: 0.4679 - val_acc: 0.9227
#
# Epoch 00033: val_acc did not improve from 0.92340
# Epoch 34/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2827 - acc: 0.9721 - val_loss: 0.4633 - val_acc: 0.9230
#
# Epoch 00034: val_acc did not improve from 0.92340
# Epoch 35/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2779 - acc: 0.9720 - val_loss: 0.4785 - val_acc: 0.9234
#
# Epoch 00035: val_acc did not improve from 0.92340
# Epoch 36/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2736 - acc: 0.9733 - val_loss: 0.4720 - val_acc: 0.9239
#
# Epoch 00036: val_acc improved from 0.92340 to 0.92390, saving model to /content/saved_models/cifar10_ResNet14v1_model.036.h5
# Epoch 37/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2684 - acc: 0.9750 - val_loss: 0.4809 - val_acc: 0.9195
#
# Epoch 00037: val_acc did not improve from 0.92390
# Epoch 38/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2635 - acc: 0.9760 - val_loss: 0.4734 - val_acc: 0.9261
#
# Epoch 00038: val_acc improved from 0.92390 to 0.92610, saving model to /content/saved_models/cifar10_ResNet14v1_model.038.h5
# Epoch 39/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2648 - acc: 0.9743 - val_loss: 0.4570 - val_acc: 0.9255
#
# Epoch 00039: val_acc did not improve from 0.92610
# Epoch 40/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2593 - acc: 0.9761 - val_loss: 0.4630 - val_acc: 0.9228
#
# Epoch 00040: val_acc did not improve from 0.92610
# Epoch 41/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2565 - acc: 0.9763 - val_loss: 0.4795 - val_acc: 0.9207
#
# Epoch 00041: val_acc did not improve from 0.92610
# Epoch 42/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2531 - acc: 0.9771 - val_loss: 0.4364 - val_acc: 0.9305
#
# Epoch 00042: val_acc improved from 0.92610 to 0.93050, saving model to /content/saved_models/cifar10_ResNet14v1_model.042.h5
# Epoch 43/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2474 - acc: 0.9783 - val_loss: 0.4663 - val_acc: 0.9233
#
# Epoch 00043: val_acc did not improve from 0.93050
# Epoch 44/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2470 - acc: 0.9774 - val_loss: 0.4814 - val_acc: 0.9195
#
# Epoch 00044: val_acc did not improve from 0.93050
# Epoch 45/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2449 - acc: 0.9785 - val_loss: 0.4584 - val_acc: 0.9257
#
# Epoch 00045: val_acc did not improve from 0.93050
# Epoch 46/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2441 - acc: 0.9777 - val_loss: 0.4589 - val_acc: 0.9279
#
# Epoch 00046: val_acc did not improve from 0.93050
# Epoch 47/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2392 - acc: 0.9794 - val_loss: 0.4530 - val_acc: 0.9290
#
# Epoch 00047: val_acc did not improve from 0.93050
# Epoch 48/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2380 - acc: 0.9791 - val_loss: 0.4718 - val_acc: 0.9255
#
# Epoch 00048: val_acc did not improve from 0.93050
# Epoch 49/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2334 - acc: 0.9810 - val_loss: 0.4409 - val_acc: 0.9297
#
# Epoch 00049: val_acc did not improve from 0.93050
# Epoch 50/50
# Learning rate:  0.0001
#  - 63s - loss: 0.2339 - acc: 0.9803 - val_loss: 0.4602 - val_acc: 0.9276
#
# Epoch 00050: val_acc did not improve from 0.93050
# 10000/10000 [==============================] - 4s 388us/step
# Test loss: 0.46024533681869506
# Test accuracy: 0.9276

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2
from keras import backend as K
import os
import matplotlib.pyplot as pltQ
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
import keras
# %matplotlib inline
from keras.datasets import cifar10

from google.colab.patches import cv2_imshow

# %%
(x_train_v, y_train_v), (x_test_v, y_test_v) = cifar10.load_data()
print(x_train_v[0])
x = np.expand_dims(x_train[0], axis=0)
# Out:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
saved_model ='/content/saved_models/cifar10_ResNet14v1_model.042.h5'

model = keras.models.load_model(saved_model)

preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("conv2d_15")
# Out:
# 6

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])
print(conv_layer_output_value.shape)

last_conv_layer_num_filters = last_conv_layer.output_shape[3]
print(last_conv_layer_num_filters)
for i in range(last_conv_layer_num_filters):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# (?, 8, 8, 440)
# (440,)
# (8, 8, 440)
# 440

# %%
heatmap = np.mean(conv_layer_output_value, axis = -1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
# Out:
# (8, 8, 440)
# (8, 8)

# %%
for i in range(10):
  img1 = x_test_v[i]
  img1 = cv2.resize(img1, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
  heatmap = cv2.resize(heatmap, (img1.shape[1], img1.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img1, 0.5, heatmap, 0.5, 0)
  cv2_imshow(img1)
  cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37C50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37978>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37C50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37978>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37C50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37978>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37C50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37978>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FD972867AC8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37978>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37C50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37DD8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37978>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FDB18E37C50>
