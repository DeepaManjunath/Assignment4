# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaManjunath/Assignment4/blob/master/Untitled40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
#Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# %%
#Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
#Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    
    lr = 1e-3
    #if epoch > 40:
     #   lr *= le-1
    #elif epoch > 30:
     #   lr *= 1e-2
    #elif epoch > 20:
     #   lr *= 1e-2
    if epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
def resnet_layer(inputs,
                 num_filters=56,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization(momentum=0.355)(x)
            x=Dropout(0.0994)(x)
          #  x=Dropout(0.13)(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization(momentum=0.355)(x)
            x=Dropout(0.0994)(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    
        
   
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 56
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
   # x = AveragePooling2D(pool_size=4)(x)
    y = GlobalAveragePooling2D()(x)
    #outputs=Activation('softmax')(y)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 1:
    
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Learning rate:  0.001
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 56)   1568        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 56)   224         conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 56)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 56)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 56)   28280       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 56)   224         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 56)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 56)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 56)   28280       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 56)   224         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 56)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 56)   0           activation_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 56)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 56)   28280       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 56)   224         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 56)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 56)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 56)   28280       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 56)   224         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 56)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 56)   0           activation_3[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 56)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 112)  56560       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 112)  448         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 112)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 112)  0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 112)  113008      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 112)  448         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 112)  6384        activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 112)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 112)  0           conv2d_8[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 112)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 112)  113008      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 112)  448         conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 112)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 112)  0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 112)  113008      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 112)  448         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 112)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 112)  0           activation_7[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 112)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 224)    226016      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 224)    896         conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8, 8, 224)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 224)    0           dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 224)    451808      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 224)    896         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 224)    25312       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 224)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 224)    0           conv2d_13[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 224)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 224)    451808      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 224)    896         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 224)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 224)    0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 224)    451808      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 224)    896         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 224)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 224)    0           activation_11[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 224)    0           add_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 224)          0           activation_13[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2250        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 2,132,154
# Trainable params: 2,128,906
# Non-trainable params: 3,248
# __________________________________________________________________________________________________
# ResNet14v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=2,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
#Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    get_random_eraser(v_l=0, v_h=1)
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        
       # get_random_eraser(v_l=0, v_h=1)
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
#Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs,verbose=2,workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/50
# Learning rate:  0.001
#  - 105s - loss: 1.3958 - acc: 0.6307 - val_loss: 1.2380 - val_acc: 0.6927
#
# Epoch 00001: val_acc improved from -inf to 0.69270, saving model to /content/saved_models/cifar10_ResNet14v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
#  - 104s - loss: 1.1423 - acc: 0.7177 - val_loss: 1.0442 - val_acc: 0.7539
#
# Epoch 00002: val_acc improved from 0.69270 to 0.75390, saving model to /content/saved_models/cifar10_ResNet14v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
#  - 104s - loss: 1.0049 - acc: 0.7629 - val_loss: 0.9569 - val_acc: 0.7872
#
# Epoch 00003: val_acc improved from 0.75390 to 0.78720, saving model to /content/saved_models/cifar10_ResNet14v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
#  - 104s - loss: 0.9193 - acc: 0.7884 - val_loss: 0.9164 - val_acc: 0.7971
#
# Epoch 00004: val_acc improved from 0.78720 to 0.79710, saving model to /content/saved_models/cifar10_ResNet14v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
#  - 104s - loss: 0.8592 - acc: 0.8072 - val_loss: 0.8692 - val_acc: 0.8082
#
# Epoch 00005: val_acc improved from 0.79710 to 0.80820, saving model to /content/saved_models/cifar10_ResNet14v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
#  - 104s - loss: 0.8111 - acc: 0.8231 - val_loss: 0.8072 - val_acc: 0.8296
#
# Epoch 00006: val_acc improved from 0.80820 to 0.82960, saving model to /content/saved_models/cifar10_ResNet14v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
#  - 104s - loss: 0.7752 - acc: 0.8335 - val_loss: 0.7938 - val_acc: 0.8304
#
# Epoch 00007: val_acc improved from 0.82960 to 0.83040, saving model to /content/saved_models/cifar10_ResNet14v1_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
#  - 104s - loss: 0.7493 - acc: 0.8422 - val_loss: 0.7392 - val_acc: 0.8459
#
# Epoch 00008: val_acc improved from 0.83040 to 0.84590, saving model to /content/saved_models/cifar10_ResNet14v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
#  - 104s - loss: 0.7274 - acc: 0.8500 - val_loss: 0.7759 - val_acc: 0.8392
#
# Epoch 00009: val_acc did not improve from 0.84590
# Epoch 10/50
# Learning rate:  0.001
#  - 104s - loss: 0.7117 - acc: 0.8546 - val_loss: 0.7131 - val_acc: 0.8567
#
# Epoch 00010: val_acc improved from 0.84590 to 0.85670, saving model to /content/saved_models/cifar10_ResNet14v1_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
#  - 103s - loss: 0.6911 - acc: 0.8623 - val_loss: 0.6775 - val_acc: 0.8698
#
# Epoch 00011: val_acc improved from 0.85670 to 0.86980, saving model to /content/saved_models/cifar10_ResNet14v1_model.011.h5
# Epoch 12/50
# Learning rate:  0.0001
#  - 104s - loss: 0.5803 - acc: 0.8995 - val_loss: 0.5878 - val_acc: 0.8942
#
# Epoch 00012: val_acc improved from 0.86980 to 0.89420, saving model to /content/saved_models/cifar10_ResNet14v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.0001
#  - 104s - loss: 0.5367 - acc: 0.9120 - val_loss: 0.5777 - val_acc: 0.8977
#
# Epoch 00013: val_acc improved from 0.89420 to 0.89770, saving model to /content/saved_models/cifar10_ResNet14v1_model.013.h5
# Epoch 14/50
# Learning rate:  0.0001
#  - 104s - loss: 0.5137 - acc: 0.9182 - val_loss: 0.5652 - val_acc: 0.9001
#
# Epoch 00014: val_acc improved from 0.89770 to 0.90010, saving model to /content/saved_models/cifar10_ResNet14v1_model.014.h5
# Epoch 15/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4982 - acc: 0.9207 - val_loss: 0.5680 - val_acc: 0.8966
#
# Epoch 00015: val_acc did not improve from 0.90010
# Epoch 16/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4795 - acc: 0.9256 - val_loss: 0.5524 - val_acc: 0.9011
#
# Epoch 00016: val_acc improved from 0.90010 to 0.90110, saving model to /content/saved_models/cifar10_ResNet14v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4663 - acc: 0.9274 - val_loss: 0.5406 - val_acc: 0.9020
#
# Epoch 00017: val_acc improved from 0.90110 to 0.90200, saving model to /content/saved_models/cifar10_ResNet14v1_model.017.h5
# Epoch 18/50
# Learning rate:  0.0001
#  - 103s - loss: 0.4544 - acc: 0.9296 - val_loss: 0.5371 - val_acc: 0.9045
#
# Epoch 00018: val_acc improved from 0.90200 to 0.90450, saving model to /content/saved_models/cifar10_ResNet14v1_model.018.h5
# Epoch 19/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4404 - acc: 0.9326 - val_loss: 0.5192 - val_acc: 0.9079
#
# Epoch 00019: val_acc improved from 0.90450 to 0.90790, saving model to /content/saved_models/cifar10_ResNet14v1_model.019.h5
# Epoch 20/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4323 - acc: 0.9350 - val_loss: 0.5211 - val_acc: 0.9038
#
# Epoch 00020: val_acc did not improve from 0.90790
# Epoch 21/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4208 - acc: 0.9371 - val_loss: 0.5037 - val_acc: 0.9086
#
# Epoch 00021: val_acc improved from 0.90790 to 0.90860, saving model to /content/saved_models/cifar10_ResNet14v1_model.021.h5
# Epoch 22/50
# Learning rate:  0.0001
#  - 104s - loss: 0.4090 - acc: 0.9391 - val_loss: 0.5078 - val_acc: 0.9105
#
# Epoch 00022: val_acc improved from 0.90860 to 0.91050, saving model to /content/saved_models/cifar10_ResNet14v1_model.022.h5
# Epoch 23/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3977 - acc: 0.9416 - val_loss: 0.5087 - val_acc: 0.9101
#
# Epoch 00023: val_acc did not improve from 0.91050
# Epoch 24/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3890 - acc: 0.9445 - val_loss: 0.5027 - val_acc: 0.9075
#
# Epoch 00024: val_acc did not improve from 0.91050
# Epoch 25/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3811 - acc: 0.9448 - val_loss: 0.4988 - val_acc: 0.9129
#
# Epoch 00025: val_acc improved from 0.91050 to 0.91290, saving model to /content/saved_models/cifar10_ResNet14v1_model.025.h5
# Epoch 26/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3751 - acc: 0.9458 - val_loss: 0.4965 - val_acc: 0.9098
#
# Epoch 00026: val_acc did not improve from 0.91290
# Epoch 27/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3682 - acc: 0.9478 - val_loss: 0.4883 - val_acc: 0.9120
#
# Epoch 00027: val_acc did not improve from 0.91290
# Epoch 28/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3578 - acc: 0.9500 - val_loss: 0.4748 - val_acc: 0.9158
#
# Epoch 00028: val_acc improved from 0.91290 to 0.91580, saving model to /content/saved_models/cifar10_ResNet14v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3522 - acc: 0.9518 - val_loss: 0.4961 - val_acc: 0.9119
#
# Epoch 00029: val_acc did not improve from 0.91580
# Epoch 30/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3446 - acc: 0.9535 - val_loss: 0.4829 - val_acc: 0.9134
#
# Epoch 00030: val_acc did not improve from 0.91580
# Epoch 31/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3414 - acc: 0.9531 - val_loss: 0.4840 - val_acc: 0.9139
#
# Epoch 00031: val_acc did not improve from 0.91580
# Epoch 32/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3341 - acc: 0.9552 - val_loss: 0.4806 - val_acc: 0.9141
#
# Epoch 00032: val_acc did not improve from 0.91580
# Epoch 33/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3283 - acc: 0.9566 - val_loss: 0.4588 - val_acc: 0.9187
#
# Epoch 00033: val_acc improved from 0.91580 to 0.91870, saving model to /content/saved_models/cifar10_ResNet14v1_model.033.h5
# Epoch 34/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3247 - acc: 0.9570 - val_loss: 0.4672 - val_acc: 0.9189
#
# Epoch 00034: val_acc improved from 0.91870 to 0.91890, saving model to /content/saved_models/cifar10_ResNet14v1_model.034.h5
# Epoch 35/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3206 - acc: 0.9570 - val_loss: 0.4822 - val_acc: 0.9117
#
# Epoch 00035: val_acc did not improve from 0.91890
# Epoch 36/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3116 - acc: 0.9603 - val_loss: 0.4662 - val_acc: 0.9154
#
# Epoch 00036: val_acc did not improve from 0.91890
# Epoch 37/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3081 - acc: 0.9603 - val_loss: 0.4618 - val_acc: 0.9185
#
# Epoch 00037: val_acc did not improve from 0.91890
# Epoch 38/50
# Learning rate:  0.0001
#  - 103s - loss: 0.3050 - acc: 0.9611 - val_loss: 0.4588 - val_acc: 0.9174
#
# Epoch 00038: val_acc did not improve from 0.91890
# Epoch 39/50
# Learning rate:  0.0001
#  - 104s - loss: 0.3019 - acc: 0.9610 - val_loss: 0.4677 - val_acc: 0.9171
#
# Epoch 00039: val_acc did not improve from 0.91890
# Epoch 40/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2917 - acc: 0.9656 - val_loss: 0.4768 - val_acc: 0.9138
#
# Epoch 00040: val_acc did not improve from 0.91890
# Epoch 41/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2883 - acc: 0.9656 - val_loss: 0.4722 - val_acc: 0.9164
#
# Epoch 00041: val_acc did not improve from 0.91890
# Epoch 42/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2869 - acc: 0.9654 - val_loss: 0.4686 - val_acc: 0.9164
#
# Epoch 00042: val_acc did not improve from 0.91890
# Epoch 43/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2806 - acc: 0.9678 - val_loss: 0.4797 - val_acc: 0.9144
#
# Epoch 00043: val_acc did not improve from 0.91890
# Epoch 44/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2772 - acc: 0.9675 - val_loss: 0.4639 - val_acc: 0.9162
#
# Epoch 00044: val_acc did not improve from 0.91890
# Epoch 45/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2749 - acc: 0.9683 - val_loss: 0.4557 - val_acc: 0.9178
#
# Epoch 00045: val_acc did not improve from 0.91890
# Epoch 46/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2718 - acc: 0.9683 - val_loss: 0.4664 - val_acc: 0.9148
#
# Epoch 00046: val_acc did not improve from 0.91890
# Epoch 47/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2671 - acc: 0.9698 - val_loss: 0.4556 - val_acc: 0.9182
#
# Epoch 00047: val_acc did not improve from 0.91890
# Epoch 48/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2647 - acc: 0.9697 - val_loss: 0.4585 - val_acc: 0.9181
#
# Epoch 00048: val_acc did not improve from 0.91890
# Epoch 49/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2601 - acc: 0.9714 - val_loss: 0.4599 - val_acc: 0.9151
#
# Epoch 00049: val_acc did not improve from 0.91890
# Epoch 50/50
# Learning rate:  0.0001
#  - 104s - loss: 0.2556 - acc: 0.9726 - val_loss: 0.4512 - val_acc: 0.9190
#
# Epoch 00050: val_acc improved from 0.91890 to 0.91900, saving model to /content/saved_models/cifar10_ResNet14v1_model.050.h5
# 10000/10000 [==============================] - 7s 686us/step
# Test loss: 0.45123893542289734
# Test accuracy: 0.919

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2
from keras import backend as K
import os
import matplotlib.pyplot as plt
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
import keras
# %matplotlib inline
from keras.datasets import cifar10

from google.colab.patches import cv2_imshow

# %%
(x_train_v, y_train_v), (x_test_v, y_test_v) = cifar10.load_data()
print(x_train_v[0])
x = np.expand_dims(x_train[0], axis=0)
# Out:
# [[[ 59  62  63]
#   [ 43  46  45]
#   [ 50  48  43]
#   ...
#   [158 132 108]
#   [152 125 102]
#   [148 124 103]]
#
#  [[ 16  20  20]
#   [  0   0   0]
#   [ 18   8   0]
#   ...
#   [123  88  55]
#   [119  83  50]
#   [122  87  57]]
#
#  [[ 25  24  21]
#   [ 16   7   0]
#   [ 49  27   8]
#   ...
#   [118  84  50]
#   [120  84  50]
#   [109  73  42]]
#
#  ...
#
#  [[208 170  96]
#   [201 153  34]
#   [198 161  26]
#   ...
#   [160 133  70]
#   [ 56  31   7]
#   [ 53  34  20]]
#
#  [[180 139  96]
#   [173 123  42]
#   [186 144  30]
#   ...
#   [184 148  94]
#   [ 97  62  34]
#   [ 83  53  34]]
#
#  [[177 144 116]
#   [168 129  94]
#   [179 142  87]
#   ...
#   [216 184 140]
#   [151 118  84]
#   [123  92  72]]]

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
saved_model ='/content/saved_models/cifar10_ResNet14v1_model.050.h5'

model = keras.models.load_model(saved_model)

preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("conv2d_15")
# Out:
# 6

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])
print(conv_layer_output_value.shape)

last_conv_layer_num_filters = last_conv_layer.output_shape[3]
print(last_conv_layer_num_filters)
for i in range(last_conv_layer_num_filters):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
# Out:
# (?, 8, 8, 224)
# (224,)
# (8, 8, 224)
# 224

# %%
heatmap = np.mean(conv_layer_output_value, axis = -1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
# Out:
# (8, 8, 224)
# (8, 8)

# %%
for i in range(10):
  img1 = x_test_v[i]
  img1 = cv2.resize(img1, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
  heatmap = cv2.resize(heatmap, (img1.shape[1], img1.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img1, 0.5, heatmap, 0.5, 0)
  cv2_imshow(img1)
  cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB95048A58>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559B0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55AC8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559B0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55AC8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55AC8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F559E8>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FEB16F55B00>
